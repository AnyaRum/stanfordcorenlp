# %%
import tweepy
import csv
import pandas as pd

# %%
#trish's twitter developer app details 
consumer_key='6DFnyG8QVDJ0HMyU47MkHYbyb'
consumer_secret='xTMGt1qi0P4EewyQAFsf1JExMaxenwWKuEscrfRwfDeBZldrqU'
access_token='1163731579455397888-TL2ZiGCEAS65ZB6sr3MbyM05kLzUFA'
access_token_secret='amd3kfZXu6go1qLpnwpQVdYIaDnVlYCWi8AXiDBhlLJuU'

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth,wait_on_rate_limit=True)
####
# Open/Create a file to append data
csvFile = open('pentaho.csv', 'a')
#Use csv Writer
csvWriter = csv.writer(csvFile)
#http://docs.tweepy.org/en/v3.5.0/api.html#API.search (API reference)
#looking for the 100 latest tweets involving the hashtag (xxxx)
for tweet in tweepy.Cursor(api.search,q="#pentaho",count=100,
                           lang="en",
                           since="2017-04-03").items():
#print the date and time and the tweet itself
    print (tweet.created_at, tweet.text)
#write the information to a csv file
    csvWriter.writerow([tweet.created_at, tweet.text.encode('utf-8')])
# Out:
# 2019-08-21 03:28:04 Throwback to 2 wks ago when @brucebHitachi taught #Pentaho CTools at @HitachiVantara Singapore. Fantastic 4-day exp… https://t.co/EBijryFb4D
# 2019-08-21 02:51:17 RT @Helical_Tech: Create a job in PDI which can export Mondrian schema which is in XML format to excel.
# #helicaltech #PDI #pentaho #pentaho…
# 2019-08-20 12:27:18 Create a job in PDI which can export Mondrian schema which is in XML format to excel.
# #helicaltech #PDI #pentaho… https://t.co/vJoAQYVaIm
# 2019-08-20 11:20:27 Pentaho - An Important Part Of Data Developers Strategy
#
# https://t.co/ifCPyD0bf3
#
# #Pentaho #developers #Technology https://t.co/I0Vw3Gnz0A
# 2019-08-20 09:27:13 Big Data Analysis Report By Pentaho Development
#
# Pentaho development is an incredible option for organizations with… https://t.co/yaKI1ATEo1
# 2019-08-19 17:45:02 "None of us is as smart as all of us." --Ken Blanchard
#
# We have successfully completed 4 years and stepping in the… https://t.co/WPiCGPHpXT
# ...

# %%
#read the csv file and organise it into a table and print
pentahoTweets=pd.read_csv('pentaho.csv', usecols=[0,1], names=["date and time", "tweet"])
pentahoTweets
# Out:
#           date and time                                              tweet
# 0   2019-08-21 03:28:04  'Throwack to 2 wks ago when @ruceHitachi taugh...
# 1   2019-08-21 02:51:17  'RT @Helical_Tech: Create a jo in PDI which ca...
# 2   2019-08-20 12:27:18  'Create a jo in PDI which can export Mondrian ...
# 3   2019-08-20 11:20:27  'Pentaho - An Important Part Of Data Developer...
# 4   2019-08-20 09:27:13  'ig Data Analysis Report y Pentaho Development...
# 5   2019-08-19 17:45:02  '"None of us is as smart as all of us." --Ken ...
# 6   2019-08-19 17:43:17  '"None of us is as smart as all of us." --Ken ...
# 7   2019-08-19 02:16:00  'RT @uweeegeee: #apacheignite #pentaho #pdi #k...
# 8   2019-08-19 02:15:58  'RT @uweeegeee: #apacheignite #pentaho #pdi #k...
# 9   2019-08-17 12:43:10  '#apacheignite #pentaho #pdi #kettle log post:...
# 10  2019-08-17 11:31:34  '#apacheignite #pentaho #pdi #kettle log post:...
# ...
